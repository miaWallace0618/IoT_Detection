# %% [markdown]
# The goal of this file is to extract data from S3 bucket, in order to build machine learning models.
#
#
# The process of extracting data is devided into 3 main parts, including installing needed resources, preparing data files and creating main functions.

# %% [markdown]
# # 1. Install Package Needed
# * watch out bat package here, bat pacakge only needs to be installed once locally, but needs to be installed everytime a new instance is created in aws cloud platform

# %%
                                                                                                                                                                                                                                                                                                                                                                                                    # The following two lines are used to install bat package.
# When first use this notebook instance, please uncomment those two lines, since they allow you to install bat package.

# !conda install -y -c conda-forge pip
# !pip install bat

# %%
# intall other needed packages

import os
import re
import boto3
import pandas as pd
import numpy as np
from sagemaker import get_execution_role
from bat import bro_multi_log_reader

# %%
# get execution role from aws
role = get_execution_role()
region = boto3.Session().region_name
bucket='sagemaker-model-ml'

# %% [markdown]
# # 2. Data Preparation

# %% [markdown]
# ## 2.1 Reading Files from S3 Bucket
# ### 2.1.1 define a class to read files
# * Define a class MultiLogToDataFrame with functions to read log files into pandas dataframe directly from S3 bucket

# %%
class MultiLogToDataFrame(pd.DataFrame):
    """MultiLogToDataFrame: Converts multiple Bro logs to a Pandas DataFrame
        Args:
            log_fllename (string): The full path to the Bro log
            ts_index (bool): Set the index to the 'ts' field (default = True)
        Notes:
            This class is fairly simple right now but will probably have additional
            functionality for formal type specifications and performance enhancements
    """
    def __init__(self, log_filename, ts_index=False):
        """Initialize the LogToDataFrame class"""

        # Create a bro reader on a given log file
        reader = bro_multi_log_reader.BroMultiLogReader(log_filename)

        # Create a Pandas dataframe from reader
        super(MultiLogToDataFrame, self).__init__(reader.readrows())

        # Set the index
        if ts_index:
            self.set_index('ts', inplace=True)

# %% [markdown]
# ### 2.1.2 download files from S3 to notebook instance
# * Download data and files needed for buidling models from S3

# %%
# Out:
# '/Users/Rachel/Desktop/AtomicIOT/Rachel/Sagemaker/Data/2018'

# %%
#download monthly log file from S3 and unzip it 

#s3 = boto3.resource('s3')
#s3.Bucket(bucket).download_file('2017-11.tgz','2017-11.tgz')

import tarfile
with tarfile.open("2017-11.tgz","r") as tar_ref:
    tar_ref.extractall("2017-11")

# %%
with tarfile.open("2018-01.tgz","r") as tar_ref:
    tar_ref.extractall("2018-01")

# %%
with tarfile.open("2018-02.tgz","r") as tar_ref:
    tar_ref.extractall("2018-02")
with tarfile.open("2018-03.tgz","r") as tar_ref:
    tar_ref.extractall("2018-03")
with tarfile.open("2018-04.tgz","r") as tar_ref:
    tar_ref.extractall("2018-04")
with tarfile.open("2018-05.tgz","r") as tar_ref:
    tar_ref.extractall("2018-05")
with tarfile.open("2018-06.tgz","r") as tar_ref:
    tar_ref.extractall("2018-06")

# %% [markdown]
# ## 2.2 Process Individual Files Downloaded
# * Four kinds of files are processed here, including conn.log files, dns.log files, http.log files and ssl.log files

# %% [markdown]
# ### 2.2.1 Prepare conn.log files
# * A function called CleanConn was defined below to complete basic processes for conn.log files.

# %%
def CleanConn(conn):
    #only external data
    #conn = conn[conn.local_resp.apply(lambda x: not x)]
    conn = conn[conn.proto == 'tcp']
    #select column
    conn = conn.drop(['tunnel_parents', 'uid'],1)
    #modify column
    if conn.duration.dtypes == 'object':
        conn['duration'] = conn.duration.replace('-', '00:00:00.00').astype('str')
        conn['duration'] = [datetime.datetime.strptime(x, "%H:%M:%S.%f") if re.match('\d+:\d+:\d+.\d+', x)
                            else datetime.datetime.strptime(x, "%d days, %H:%M:%S.%f") if 'days' in x
                            else datetime.datetime.strptime(x, "%d day, %H:%M:%S.%f") if 'day' in x
                            else datetime.datetime.strptime(x, "%H:%M:%S") for x in conn.duration]
        conn['duration'] = conn.duration.apply(lambda x :
                                               datetime.timedelta(hours=x.hour, minutes=x.minute, seconds=x.second))
    conn.service = conn.service.replace('-',np.NaN)
    return conn

# %% [markdown]
# ### 2.2.2 Prepare dns.log files
# * A function called CleanDns was defined below to complete basic processes for dns.log files.

# %%
def CleanDns(dns):
    dns.is_copy = False
    #select column
    dns = dns[['id.orig_h', 'id.orig_p', 'id.resp_h', 'ts','id.resp_p', 'query']]
    #modify column
    dns.loc[:, 'query'] = dns['query'].str.replace('\*[\\\\x00]{1,}', 'Unknown')
    dns.loc[:, 'query'] = dns['query'].str.split('.').apply(lambda x: x[-2] if len(x)>1 else x[0])
    return dns

# %% [markdown]
# ### 2.2.3 Prepare http.log files
# * A function called CleanHttp was defined below to complete basic processes for http.log files.

# %%
def CleanHttp(http):
    http.is_copy = False
    #select column
    http = http[['id.orig_h', 'id.orig_p', 'id.resp_h','ts', 'id.resp_p', 'uri', 'user_agent', 'host']]
    return http

# %% [markdown]
# ### 2.2.4 Prepare ssl.log files
# * A function called CleanSsl was defined below to complete basic processes for ssl.log files.

# %%
def CleanSsl(ssl):
    #select column
    ssl = ssl[['id.orig_h','id.orig_p','id.resp_h','id.resp_p','ts','subject','cert_chain_fuids']]
    return ssl

# %% [markdown]
# ## 2.3 Define Mapping Functions
# * Four mapping functions were defined below, including Aug_Mapping, Aug_Other, Oct_Mapping and Oct_other.
# * These four mapping functions were used to create our training and testing data, based on network traffic and device inside atomic model, using MAC address of each device as primary key.

# %% [markdown]
# ### 2.3.1 Aug_Mapping and Aug_Other

# %%
def Aug_Mapping(conn,Macone,MacExa,IPLook):
    conn2 = conn[[True if x in IPLook['IOT'].keys() else False for x in conn['id.orig_h']]]
    conn2.is_copy=False
    conn2['mac'] = [Macone.mac[y].values for y in [Macone.assigned_ip == x for x in conn2['id.orig_h']]]
    conn2['IOT'] = [Macone.IOT[y].values for y in [Macone.assigned_ip == x for x in conn2['id.orig_h']]]
    conn2['Device'] = [Macone.Device[y].values for y in [Macone.assigned_ip == x for x in conn2['id.orig_h']]]
    #
    for index, row in conn2.reset_index()[['ts','id.orig_h','mac','IOT','Device']].iterrows():
        for i , r in MacExa.iterrows():
            if row['ts'] >= r['min_ts'] and row['ts'] <= r['max_ts'] and row['id.orig_h'] == r['assigned_ip']:
                row['mac'] = r['mac']
                row['IOT'] = r['IOT']
                row['Device'] = r['Device']
            else:
                continue
    return conn2

def Aug_Other(df, Macone, MacExa, IPLook):
    df2 = df[[True if x in IPLook['IOT'].keys() else False for x in df['id.orig_h']]]
    df2.is_copy = False
    df2['mac'] = [Macone.mac[y].values for y in [Macone.assigned_ip == x for x in df2['id.orig_h']]]
    #
    for index, row in df2.reset_index()[['ts', 'id.orig_h', 'mac', 'IOT', 'Device']].iterrows():
        for i, r in MacExa.iterrows():
            if row['ts'] >= r['min_ts'] and row['ts'] <= r['max_ts'] and row['id.orig_h'] == r['assigned_ip']:
                row['mac'] = r['mac']
            else:
                continue
    return df2

# %% [markdown]
# ### 2.3.2 Oct_Mapping and Oct_Other

# %%
def Oct_Mapping(conn,Oct_Mac):
    conn2 = conn[[True if x in Oct_Mac.assigned_ip.values else False for x in conn['id.orig_h']]]
    conn2['mac'] = [Oct_Mac.mac[y].values[0] for y in [Oct_Mac.assigned_ip == x for x in conn2['id.orig_h']]]
    conn2['IOT'] = [Oct_Mac.IOT[y].values[0] for y in [Oct_Mac.assigned_ip == x for x in conn2['id.orig_h']]]
    conn2['Device'] = [Oct_Mac.Device[y].values[0] for y in [Oct_Mac.assigned_ip == x for x in conn2['id.orig_h']]]
    return conn2

def Oct_Other(df, Oct_Mac):
    df2 = df[[True if x in Oct_Mac.assigned_ip.values else False for x in df['id.orig_h']]]
    df2['mac'] = [Oct_Mac.mac[y].values[0] for y in [Oct_Mac.assigned_ip == x for x in df['id.orig_h']]]

# %% [markdown]
# # 3. Create Main Function
# * In the body of this function, two sets of parameters used in mapping process were defined, these two include:
#     * IPLook & DeviceLook
#     * Macone & MacExa

# %%
def main(filepath,month):
    
    # prepare IPLook and DeviceLook
    IPrefer = pd.read_excel('IOT.xlsx', header=None)
    IPrefer.columns = ['refer', 'IOT', 'Manufactor', 'Device','Other']
    IPrefer.refer = IPrefer.refer.apply(lambda x: '192.168.0.' + x)
    IPrefer.loc[:, 'refer'] = IPrefer.refer.str.split('-', expand=True)[0]
    IPrefer = IPrefer.apply(lambda x: x.str.strip())
    IPLook = IPrefer[['refer', 'IOT']].set_index('refer').to_dict()
    DeviceLook = IPrefer[['refer', 'Device']].set_index('refer').to_dict()
    
    # prepare Macone and MacExa
    Oct_Mac = pd.read_csv('/Users/Rachel/Desktop/AtomicIOT/Rachel/Sagemaker/Data/OCT_mac.csv')
    Aug_Mac = pd.read_excel('/Users/Rachel/Desktop/AtomicIOT/Rachel/Sagemaker/Data/Aug_DHCP.xlsx')
    Aug_Mac.loc[:, 'IOT'] = [IPLook['IOT'][x] for x in Aug_Mac.assigned_ip]
    Aug_Mac.loc[:, 'Device'] = [DeviceLook['Device'][x] for x in Aug_Mac.assigned_ip]
    DupIP = Aug_Mac.groupby('assigned_ip').mac.count()[Aug_Mac.groupby('assigned_ip').mac.count() > 1].index.values
    DupMac = Aug_Mac.groupby('mac').assigned_ip.count()[Aug_Mac.groupby('mac').assigned_ip.count() > 1].index.values
    Aug_Mac.loc[Aug_Mac.mac == DupMac[0], 'Device'] = 'Gaming'
    Aug_Mac.loc[41, 'Device'] = 'Mobile'
    Macone = Aug_Mac[Aug_Mac.assigned_ip.apply(lambda x: x not in DupIP)]
    Macdup = Aug_Mac[Aug_Mac.assigned_ip.apply(lambda x: x in DupIP)]
    Macone = Macone.append(Macdup[Macdup.mac.apply(lambda x: x in DupMac[0])], ignore_index=True)
    MacExa = Macdup[~Macdup.mac.apply(lambda x: x in DupMac[0])]
    
    for i in range(1, 32):
        print(i)
        if i <= 9 :
            i = '0'+str(i)
        else:
            i = str(i)
        conn = MultiLogToDataFrame(filepath+
                                   '2017-' + month + '/'
                                   '2017-' + month + '-' + i +'/conn.*.log.gz')
        conn = CleanConn(conn)
        if month == '08':
            conn2 = Aug_Mapping(conn,Macone,MacExa,IPLook)
        else:
            conn2 = Oct_Mapping(conn,Oct_Mac)
            
        dns = MultiLogToDataFrame(filepath +
                                  '2017-' + month + '/'
                                  '2017-' + month + '-' + i + '/dns.*.log.gz')
        dns = CleanDns(dns)
        if month == '08':
            dns2 = Aug_Mapping(dns,Macone,MacExa,IPLook)
        else:
            dns2 = Oct_Mapping(dns,Oct_Mac)
            
        http = MultiLogToDataFrame(filepath +
                                   '2017-' + month + '/'
                                   '2017-' + month + '-' + i + '/http.*.log.gz')
        http = CleanHttp(http)
        if month == '08':
            http2 = Aug_Mapping(http,Macone,MacExa,IPLook)
        else:
            http2 = Oct_Mapping(http,Oct_Mac)
            
        ssl = MultiLogToDataFrame(filepath +
                                  '2017-' + month + '/'
                                  '2017-' + month + '-' + i + '/ssl.*.log.gz')
        ssl = CleanSsl(ssl)
        if month == '08':
            ssl2 = Aug_Mapping(ssl,Macone,MacExa,IPLook)
        else:
            ssl2 = Oct_Mapping(ssl,Oct_Mac)

        conn2.to_csv('test_data/conn_'+month+'_'+i+'.csv',index=False)
        dns2.to_csv('test_data/dns_'+month+'_'+i+'.csv',index=False)
        http2.to_csv('test_data/http_'+month+'_'+i+'.csv',index=False)
        ssl2.to_csv('test_data/ssl_'+month+'_'+i+'.csv',index=False)

# %%
# calling the main function to write processed data into test_data folder

# %%time
filepath = '/home/ec2-user/SageMaker/AtomicMole-Model/'
main(filepath, '11')
# Out:
# 1
# Successfully monitoring /tmp/tmpw9sdpqga...
# Removed temporary file /tmp/tmpw9sdpqga...
# Successfully monitoring /tmp/tmplr7ae7jc...
# Removed temporary file /tmp/tmplr7ae7jc...
# Successfully monitoring /tmp/tmptwhqskph...
# Removed temporary file /tmp/tmptwhqskph...
# Successfully monitoring /tmp/tmpceagjxlf...
# Removed temporary file /tmp/tmpceagjxlf...
# Successfully monitoring /tmp/tmp9le1dj52...
# Removed temporary file /tmp/tmp9le1dj52...
# Successfully monitoring /tmp/tmp0y_a_9s2...
# Removed temporary file /tmp/tmp0y_a_9s2...
# Successfully monitoring /tmp/tmpfu2dem4c...
# Removed temporary file /tmp/tmpfu2dem4c...
# Successfully monitoring /tmp/tmpibmfbsf4...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Removed temporary file /tmp/tmpibmfbsf4...
# Successfully monitoring /tmp/tmpbf14r5zm...
# Removed temporary file /tmp/tmpbf14r5zm...
# Successfully monitoring /tmp/tmp98qfzhmz...
# Removed temporary file /tmp/tmp98qfzhmz...
# Successfully monitoring /tmp/tmp9qgnpuyd...
# Removed temporary file /tmp/tmp9qgnpuyd...
# Successfully monitoring /tmp/tmpfa3t2hu3...
# Removed temporary file /tmp/tmpfa3t2hu3...
# Successfully monitoring /tmp/tmpbj4fig0m...
# Removed temporary file /tmp/tmpbj4fig0m...
# Successfully monitoring /tmp/tmp0e87t369...
# Removed temporary file /tmp/tmp0e87t369...
# Successfully monitoring /tmp/tmp9aj0yjcx...
# Removed temporary file /tmp/tmp9aj0yjcx...
# Successfully monitoring /tmp/tmp0m_r_yd3...
# Removed temporary file /tmp/tmp0m_r_yd3...
# 2
# Successfully monitoring /tmp/tmpei9oax_q...
# Removed temporary file /tmp/tmpei9oax_q...
# Successfully monitoring /tmp/tmpkps_h6bw...
# Removed temporary file /tmp/tmpkps_h6bw...
# Successfully monitoring /tmp/tmp3kiidaxs...
# Removed temporary file /tmp/tmp3kiidaxs...
# Successfully monitoring /tmp/tmpils4y3lf...
# Removed temporary file /tmp/tmpils4y3lf...
# Successfully monitoring /tmp/tmp7turmjwr...
# Removed temporary file /tmp/tmp7turmjwr...
# Successfully monitoring /tmp/tmpxzkk0dfd...
# Removed temporary file /tmp/tmpxzkk0dfd...
# Successfully monitoring /tmp/tmpclm7nqse...
# Removed temporary file /tmp/tmpclm7nqse...
# Successfully monitoring /tmp/tmp9g_yesf6...
# Removed temporary file /tmp/tmp9g_yesf6...
# Successfully monitoring /tmp/tmphc0zk67a...
# Removed temporary file /tmp/tmphc0zk67a...
# Successfully monitoring /tmp/tmpuur8flol...
# Removed temporary file /tmp/tmpuur8flol...
# Successfully monitoring /tmp/tmpli01v81w...
# Removed temporary file /tmp/tmpli01v81w...
# Successfully monitoring /tmp/tmpv46d3e6u...
# Removed temporary file /tmp/tmpv46d3e6u...
# Successfully monitoring /tmp/tmp50ky1mkc...
# Removed temporary file /tmp/tmp50ky1mkc...
# Successfully monitoring /tmp/tmp78rh2et5...
# Removed temporary file /tmp/tmp78rh2et5...
# Successfully monitoring /tmp/tmpp1g0hicd...
# Removed temporary file /tmp/tmpp1g0hicd...
# Successfully monitoring /tmp/tmp54mxhpbr...
# Removed temporary file /tmp/tmp54mxhpbr...
# 3
# Successfully monitoring /tmp/tmp2zllonho...
# Removed temporary file /tmp/tmp2zllonho...
# Successfully monitoring /tmp/tmp9v4v5lqr...
# Removed temporary file /tmp/tmp9v4v5lqr...
# Successfully monitoring /tmp/tmp10f7xsf1...
# Removed temporary file /tmp/tmp10f7xsf1...
# Successfully monitoring /tmp/tmp6zv2tzw7...
# Removed temporary file /tmp/tmp6zv2tzw7...
# Successfully monitoring /tmp/tmp2u64c3i3...
# Removed temporary file /tmp/tmp2u64c3i3...
# Successfully monitoring /tmp/tmp13lfpx9c...
# Removed temporary file /tmp/tmp13lfpx9c...
# Successfully monitoring /tmp/tmp2nxrd20r...
# Removed temporary file /tmp/tmp2nxrd20r...
# Successfully monitoring /tmp/tmpp01nczl5...
# Removed temporary file /tmp/tmpp01nczl5...
# Successfully monitoring /tmp/tmp2t58k41c...
# Removed temporary file /tmp/tmp2t58k41c...
# Successfully monitoring /tmp/tmpl6ffjqdq...
# Removed temporary file /tmp/tmpl6ffjqdq...
# Successfully monitoring /tmp/tmp7fazkryr...
# Removed temporary file /tmp/tmp7fazkryr...
# Successfully monitoring /tmp/tmp82_hb20r...
# Removed temporary file /tmp/tmp82_hb20r...
# Successfully monitoring /tmp/tmp0mciq_q9...
# Removed temporary file /tmp/tmp0mciq_q9...
# Successfully monitoring /tmp/tmpvmv14935...
# Removed temporary file /tmp/tmpvmv14935...
# Successfully monitoring /tmp/tmpnynnw0qs...
# Removed temporary file /tmp/tmpnynnw0qs...
# Successfully monitoring /tmp/tmpqjd4c60z...
# Removed temporary file /tmp/tmpqjd4c60z...
# 4
# Successfully monitoring /tmp/tmpxhhouhmv...
# Removed temporary file /tmp/tmpxhhouhmv...
# Successfully monitoring /tmp/tmperg4j4vu...
# Removed temporary file /tmp/tmperg4j4vu...
# Successfully monitoring /tmp/tmph2595_sr...
# Removed temporary file /tmp/tmph2595_sr...
# Successfully monitoring /tmp/tmpxgu1c87p...
# Removed temporary file /tmp/tmpxgu1c87p...
# Successfully monitoring /tmp/tmph21_6ze_...
# Removed temporary file /tmp/tmph21_6ze_...
# Successfully monitoring /tmp/tmpg1yg8nam...
# Removed temporary file /tmp/tmpg1yg8nam...
# Successfully monitoring /tmp/tmp6532g1sb...
# Removed temporary file /tmp/tmp6532g1sb...
# Successfully monitoring /tmp/tmp5yx1dyyj...
# Removed temporary file /tmp/tmp5yx1dyyj...
# Successfully monitoring /tmp/tmpfosect6k...
# Removed temporary file /tmp/tmpfosect6k...
# Successfully monitoring /tmp/tmpj6aynhay...
# Removed temporary file /tmp/tmpj6aynhay...
# Successfully monitoring /tmp/tmpbgsom3i7...
# Removed temporary file /tmp/tmpbgsom3i7...
# Successfully monitoring /tmp/tmpl71qbq4h...
# Removed temporary file /tmp/tmpl71qbq4h...
# Successfully monitoring /tmp/tmpqq2lyz3a...
# Removed temporary file /tmp/tmpqq2lyz3a...
# Successfully monitoring /tmp/tmp33igv259...
# Removed temporary file /tmp/tmp33igv259...
# Successfully monitoring /tmp/tmpezugpweg...
# Removed temporary file /tmp/tmpezugpweg...
# Successfully monitoring /tmp/tmpv835v6fp...
# Removed temporary file /tmp/tmpv835v6fp...
# 5
# Successfully monitoring /tmp/tmpd1gi11wy...
# Removed temporary file /tmp/tmpd1gi11wy...
# Successfully monitoring /tmp/tmpjyfylekz...
# Removed temporary file /tmp/tmpjyfylekz...
# Successfully monitoring /tmp/tmpg92c_xrw...
# Removed temporary file /tmp/tmpg92c_xrw...
# Successfully monitoring /tmp/tmppdjfj_3m...
# Removed temporary file /tmp/tmppdjfj_3m...
# Successfully monitoring /tmp/tmp80avy5nv...
# Removed temporary file /tmp/tmp80avy5nv...
# Successfully monitoring /tmp/tmpngf991d3...
# Removed temporary file /tmp/tmpngf991d3...
# Successfully monitoring /tmp/tmpzxmgl1kc...
# Removed temporary file /tmp/tmpzxmgl1kc...
# Successfully monitoring /tmp/tmpwz8mqmco...
# Removed temporary file /tmp/tmpwz8mqmco...
# Successfully monitoring /tmp/tmpzu_mpgq_...
# Removed temporary file /tmp/tmpzu_mpgq_...
# Successfully monitoring /tmp/tmpo7ut11yo...
# Removed temporary file /tmp/tmpo7ut11yo...
# Successfully monitoring /tmp/tmprrhgcg94...
# Removed temporary file /tmp/tmprrhgcg94...
# Successfully monitoring /tmp/tmpv6bgc04h...
# Removed temporary file /tmp/tmpv6bgc04h...
# Successfully monitoring /tmp/tmpc5akv2wv...
# Removed temporary file /tmp/tmpc5akv2wv...
# Successfully monitoring /tmp/tmppcs2xtzz...
# Removed temporary file /tmp/tmppcs2xtzz...
# Successfully monitoring /tmp/tmp4sc_pkqm...
# Removed temporary file /tmp/tmp4sc_pkqm...
# Successfully monitoring /tmp/tmpd6tbl0ph...
# Removed temporary file /tmp/tmpd6tbl0ph...
# Successfully monitoring /tmp/tmp9s7rtlss...
# Removed temporary file /tmp/tmp9s7rtlss...
# Successfully monitoring /tmp/tmp3diiu3u1...
# Removed temporary file /tmp/tmp3diiu3u1...
# Successfully monitoring /tmp/tmp_fam2djh...
# Removed temporary file /tmp/tmp_fam2djh...
# Successfully monitoring /tmp/tmpe4cd8xkg...
# Removed temporary file /tmp/tmpe4cd8xkg...
# 6
# Successfully monitoring /tmp/tmppyw89tby...
# Removed temporary file /tmp/tmppyw89tby...
# Successfully monitoring /tmp/tmpuqn3ysaq...
# Removed temporary file /tmp/tmpuqn3ysaq...
# Successfully monitoring /tmp/tmpcywbu1j7...
# Removed temporary file /tmp/tmpcywbu1j7...
# Successfully monitoring /tmp/tmpmegdda6i...
# Removed temporary file /tmp/tmpmegdda6i...
# Successfully monitoring /tmp/tmpp6r8kp38...
# Removed temporary file /tmp/tmpp6r8kp38...
# Successfully monitoring /tmp/tmpxqsiliim...
# Removed temporary file /tmp/tmpxqsiliim...
# Successfully monitoring /tmp/tmp0ons855t...
# Removed temporary file /tmp/tmp0ons855t...
# Successfully monitoring /tmp/tmpf6mnqp_y...
# Removed temporary file /tmp/tmpf6mnqp_y...
# Successfully monitoring /tmp/tmppyzdb7_h...
# Removed temporary file /tmp/tmppyzdb7_h...
# Successfully monitoring /tmp/tmp0aooqb1t...
# Removed temporary file /tmp/tmp0aooqb1t...
# Successfully monitoring /tmp/tmp_hdpmc1k...
# Removed temporary file /tmp/tmp_hdpmc1k...
# Successfully monitoring /tmp/tmpicgrpyld...
# Removed temporary file /tmp/tmpicgrpyld...
# Successfully monitoring /tmp/tmpurvt2nz6...
# Removed temporary file /tmp/tmpurvt2nz6...
# Successfully monitoring /tmp/tmpyqa2u9lo...
# Removed temporary file /tmp/tmpyqa2u9lo...
# Successfully monitoring /tmp/tmppdz1anj9...
# Removed temporary file /tmp/tmppdz1anj9...
# Successfully monitoring /tmp/tmpjng2nkxe...
# Removed temporary file /tmp/tmpjng2nkxe...
# 7
# Successfully monitoring /tmp/tmpr914y6gi...
# Removed temporary file /tmp/tmpr914y6gi...
# Successfully monitoring /tmp/tmp0w57i34s...
# Removed temporary file /tmp/tmp0w57i34s...
# Successfully monitoring /tmp/tmpddnf948r...
# Removed temporary file /tmp/tmpddnf948r...
# Successfully monitoring /tmp/tmpup0u0unz...
# Removed temporary file /tmp/tmpup0u0unz...
# Successfully monitoring /tmp/tmpgtjdz7eu...
# Removed temporary file /tmp/tmpgtjdz7eu...
# Successfully monitoring /tmp/tmpnh73t_qw...
# Removed temporary file /tmp/tmpnh73t_qw...
# Successfully monitoring /tmp/tmpnrsmjn15...
# Removed temporary file /tmp/tmpnrsmjn15...
# Successfully monitoring /tmp/tmp_3geph26...
# Removed temporary file /tmp/tmp_3geph26...
# Successfully monitoring /tmp/tmp7v5wsm_z...
# Removed temporary file /tmp/tmp7v5wsm_z...
# Successfully monitoring /tmp/tmpn5xbn5ec...
# Removed temporary file /tmp/tmpn5xbn5ec...
# Successfully monitoring /tmp/tmpw8_lreug...
# Removed temporary file /tmp/tmpw8_lreug...
# Successfully monitoring /tmp/tmpn76og438...
# Removed temporary file /tmp/tmpn76og438...
# Successfully monitoring /tmp/tmpnjugorfe...
# Removed temporary file /tmp/tmpnjugorfe...
# Successfully monitoring /tmp/tmpdglf14fy...
# Removed temporary file /tmp/tmpdglf14fy...
# Successfully monitoring /tmp/tmpz9rhwfaq...
# Removed temporary file /tmp/tmpz9rhwfaq...
# Successfully monitoring /tmp/tmpsaie_0ca...
# Removed temporary file /tmp/tmpsaie_0ca...
# 8
# Successfully monitoring /tmp/tmphm7feo0a...
# Removed temporary file /tmp/tmphm7feo0a...
# Successfully monitoring /tmp/tmpfqwuoi7z...
# Removed temporary file /tmp/tmpfqwuoi7z...
# Successfully monitoring /tmp/tmpekgrsnot...
# Removed temporary file /tmp/tmpekgrsnot...
# Successfully monitoring /tmp/tmpdzoruupw...
# Removed temporary file /tmp/tmpdzoruupw...
# Successfully monitoring /tmp/tmpiqzfny7p...
# Removed temporary file /tmp/tmpiqzfny7p...
# Successfully monitoring /tmp/tmp5n7soo3k...
# Removed temporary file /tmp/tmp5n7soo3k...
# Successfully monitoring /tmp/tmpuizu8eak...
# Removed temporary file /tmp/tmpuizu8eak...
# Successfully monitoring /tmp/tmpy0ywmqrz...
# Removed temporary file /tmp/tmpy0ywmqrz...
# Successfully monitoring /tmp/tmp9xqk_6ar...
# Removed temporary file /tmp/tmp9xqk_6ar...
# Successfully monitoring /tmp/tmpx066wg8_...
# Removed temporary file /tmp/tmpx066wg8_...
# Successfully monitoring /tmp/tmp13im8ryj...
# Removed temporary file /tmp/tmp13im8ryj...
# Successfully monitoring /tmp/tmp7y24a6va...
# Removed temporary file /tmp/tmp7y24a6va...
# Successfully monitoring /tmp/tmp5ahr9n27...
# Removed temporary file /tmp/tmp5ahr9n27...
# Successfully monitoring /tmp/tmpx00fb2w9...
# Removed temporary file /tmp/tmpx00fb2w9...
# Successfully monitoring /tmp/tmphpphypbk...
# Removed temporary file /tmp/tmphpphypbk...
# Successfully monitoring /tmp/tmpb3tmd0_c...
# Removed temporary file /tmp/tmpb3tmd0_c...
# 9
# Successfully monitoring /tmp/tmpw_rw2avm...
# Removed temporary file /tmp/tmpw_rw2avm...
# Successfully monitoring /tmp/tmp5mlk57p3...
# Removed temporary file /tmp/tmp5mlk57p3...
# Successfully monitoring /tmp/tmpeohx_1ag...
# Removed temporary file /tmp/tmpeohx_1ag...
# Successfully monitoring /tmp/tmpt8scw7zr...
# Removed temporary file /tmp/tmpt8scw7zr...
# Successfully monitoring /tmp/tmp3789_z6v...
# Removed temporary file /tmp/tmp3789_z6v...
# Successfully monitoring /tmp/tmpe8cykdn7...
# Removed temporary file /tmp/tmpe8cykdn7...
# Successfully monitoring /tmp/tmppn7n15ct...
# Removed temporary file /tmp/tmppn7n15ct...
# Successfully monitoring /tmp/tmpu4r_r2gc...
# Removed temporary file /tmp/tmpu4r_r2gc...
# Successfully monitoring /tmp/tmpjbfntuqq...
# Removed temporary file /tmp/tmpjbfntuqq...
# Successfully monitoring /tmp/tmpm0zah4yk...
# Removed temporary file /tmp/tmpm0zah4yk...
# Successfully monitoring /tmp/tmpvos0198j...
# Removed temporary file /tmp/tmpvos0198j...
# Successfully monitoring /tmp/tmpfcl4o6vh...
# Removed temporary file /tmp/tmpfcl4o6vh...
# Successfully monitoring /tmp/tmpvg8otsrg...
# Removed temporary file /tmp/tmpvg8otsrg...
# Successfully monitoring /tmp/tmp72almsuh...
# Removed temporary file /tmp/tmp72almsuh...
# Successfully monitoring /tmp/tmppd4uqu3a...
# Removed temporary file /tmp/tmppd4uqu3a...
# Successfully monitoring /tmp/tmpwi49r35y...
# Removed temporary file /tmp/tmpwi49r35y...
# 10
# Successfully monitoring /tmp/tmptej_0_z_...
# Removed temporary file /tmp/tmptej_0_z_...
# Successfully monitoring /tmp/tmptt17h0rn...
# Removed temporary file /tmp/tmptt17h0rn...
# Successfully monitoring /tmp/tmp0j9wb80j...
# Removed temporary file /tmp/tmp0j9wb80j...
# Successfully monitoring /tmp/tmp_2agcay2...
# Removed temporary file /tmp/tmp_2agcay2...
# Successfully monitoring /tmp/tmpq4gn_fuk...
# Removed temporary file /tmp/tmpq4gn_fuk...
# Successfully monitoring /tmp/tmprxo2kte8...
# Removed temporary file /tmp/tmprxo2kte8...
# Successfully monitoring /tmp/tmpkbv3fjno...
# Removed temporary file /tmp/tmpkbv3fjno...
# Successfully monitoring /tmp/tmpf2owyilw...
# Removed temporary file /tmp/tmpf2owyilw...
# Successfully monitoring /tmp/tmpp11z33un...
# Removed temporary file /tmp/tmpp11z33un...
# Successfully monitoring /tmp/tmpqltvxpkx...
# Removed temporary file /tmp/tmpqltvxpkx...
# Successfully monitoring /tmp/tmpuvbu4qkp...
# Removed temporary file /tmp/tmpuvbu4qkp...
# Successfully monitoring /tmp/tmp04uie5gj...
# Removed temporary file /tmp/tmp04uie5gj...
# Successfully monitoring /tmp/tmpiqmfpk61...
# Removed temporary file /tmp/tmpiqmfpk61...
# Successfully monitoring /tmp/tmp1jtvx1ig...
# Removed temporary file /tmp/tmp1jtvx1ig...
# Successfully monitoring /tmp/tmpuye11bis...
# Removed temporary file /tmp/tmpuye11bis...
# Successfully monitoring /tmp/tmpb9y96tvx...
# Removed temporary file /tmp/tmpb9y96tvx...
# 11
# Successfully monitoring /tmp/tmpo6ina_4k...
# Removed temporary file /tmp/tmpo6ina_4k...
# Successfully monitoring /tmp/tmp6k1wmuv0...
# Removed temporary file /tmp/tmp6k1wmuv0...
# Successfully monitoring /tmp/tmprcrt3ofv...
# Removed temporary file /tmp/tmprcrt3ofv...
# Successfully monitoring /tmp/tmpiu35kwn_...
# Removed temporary file /tmp/tmpiu35kwn_...
# Successfully monitoring /tmp/tmp9z5lj4jq...
# Removed temporary file /tmp/tmp9z5lj4jq...
# Successfully monitoring /tmp/tmp2f_52264...
# Removed temporary file /tmp/tmp2f_52264...
# Successfully monitoring /tmp/tmpfg3m0_i6...
# Removed temporary file /tmp/tmpfg3m0_i6...
# Successfully monitoring /tmp/tmpouaza6mh...
# Removed temporary file /tmp/tmpouaza6mh...
# Successfully monitoring /tmp/tmpc8kxotyg...
# Removed temporary file /tmp/tmpc8kxotyg...
# Successfully monitoring /tmp/tmpbw8a128q...
# Removed temporary file /tmp/tmpbw8a128q...
# Successfully monitoring /tmp/tmp0adq2vwe...
# Removed temporary file /tmp/tmp0adq2vwe...
# Successfully monitoring /tmp/tmpwy14ketg...
# Removed temporary file /tmp/tmpwy14ketg...
# Successfully monitoring /tmp/tmp8ynbaftz...
# Removed temporary file /tmp/tmp8ynbaftz...
# Successfully monitoring /tmp/tmpyso9jk9o...
# Removed temporary file /tmp/tmpyso9jk9o...
# Successfully monitoring /tmp/tmptxeao7oo...
# Removed temporary file /tmp/tmptxeao7oo...
# Successfully monitoring /tmp/tmpbsnpip81...
# Removed temporary file /tmp/tmpbsnpip81...
# 12
# Successfully monitoring /tmp/tmpl24teag0...
# Removed temporary file /tmp/tmpl24teag0...
# Successfully monitoring /tmp/tmp52tujp_g...
# Removed temporary file /tmp/tmp52tujp_g...
# Successfully monitoring /tmp/tmpox7ufydr...
# Removed temporary file /tmp/tmpox7ufydr...
# Successfully monitoring /tmp/tmpjo7rqi4_...
# Removed temporary file /tmp/tmpjo7rqi4_...
# Successfully monitoring /tmp/tmpdik95zw6...
# Removed temporary file /tmp/tmpdik95zw6...
# Successfully monitoring /tmp/tmpf0ta3dk2...
# Removed temporary file /tmp/tmpf0ta3dk2...
# Successfully monitoring /tmp/tmpa6ammdii...
# Removed temporary file /tmp/tmpa6ammdii...
# Successfully monitoring /tmp/tmpgmxe1xf0...
# Removed temporary file /tmp/tmpgmxe1xf0...
# Successfully monitoring /tmp/tmpsiv_4qvm...
# Removed temporary file /tmp/tmpsiv_4qvm...
# Successfully monitoring /tmp/tmp00g2xiwc...
# Removed temporary file /tmp/tmp00g2xiwc...
# Successfully monitoring /tmp/tmpuoilicnd...
# Removed temporary file /tmp/tmpuoilicnd...
# Successfully monitoring /tmp/tmpms_ghnff...
# Removed temporary file /tmp/tmpms_ghnff...
# Successfully monitoring /tmp/tmpft22qjoa...
# Removed temporary file /tmp/tmpft22qjoa...
# Successfully monitoring /tmp/tmplnuhh6ft...
# Removed temporary file /tmp/tmplnuhh6ft...
# Successfully monitoring /tmp/tmpe1f14xo8...
# Removed temporary file /tmp/tmpe1f14xo8...
# Successfully monitoring /tmp/tmpgef_masb...
# Removed temporary file /tmp/tmpgef_masb...
# 13
# Successfully monitoring /tmp/tmpeka6dnp0...
# Removed temporary file /tmp/tmpeka6dnp0...
# Successfully monitoring /tmp/tmpw1vw4fum...
# Removed temporary file /tmp/tmpw1vw4fum...
# Successfully monitoring /tmp/tmp244gv1cp...
# Removed temporary file /tmp/tmp244gv1cp...
# Successfully monitoring /tmp/tmp7aliguei...
# Removed temporary file /tmp/tmp7aliguei...
# Successfully monitoring /tmp/tmp5zt67irz...
# Removed temporary file /tmp/tmp5zt67irz...
# Successfully monitoring /tmp/tmprzcvxypt...
# Removed temporary file /tmp/tmprzcvxypt...
# Successfully monitoring /tmp/tmpduktai_2...
# Removed temporary file /tmp/tmpduktai_2...
# Successfully monitoring /tmp/tmplal04f1o...
# Removed temporary file /tmp/tmplal04f1o...
# Successfully monitoring /tmp/tmp8lcg191j...
# Removed temporary file /tmp/tmp8lcg191j...
# Successfully monitoring /tmp/tmpnahthnef...
# Removed temporary file /tmp/tmpnahthnef...
# Successfully monitoring /tmp/tmpt8hb8hlk...
# Removed temporary file /tmp/tmpt8hb8hlk...
# Successfully monitoring /tmp/tmphm4647zp...
# Removed temporary file /tmp/tmphm4647zp...
# Successfully monitoring /tmp/tmp5pre9chu...
# Removed temporary file /tmp/tmp5pre9chu...
# Successfully monitoring /tmp/tmpsa3ttka4...
# Removed temporary file /tmp/tmpsa3ttka4...
# Successfully monitoring /tmp/tmpcg50l5rw...
# Removed temporary file /tmp/tmpcg50l5rw...
# Successfully monitoring /tmp/tmp6zhlpgmg...
# Removed temporary file /tmp/tmp6zhlpgmg...
# 14
# Successfully monitoring /tmp/tmpo1_ibg87...
# Removed temporary file /tmp/tmpo1_ibg87...
# Successfully monitoring /tmp/tmp921jxos9...
# Removed temporary file /tmp/tmp921jxos9...
# Successfully monitoring /tmp/tmpftcbfwzc...
# Removed temporary file /tmp/tmpftcbfwzc...
# Successfully monitoring /tmp/tmpexydfvdn...
# Removed temporary file /tmp/tmpexydfvdn...
# Successfully monitoring /tmp/tmpxtspgqw9...
# Removed temporary file /tmp/tmpxtspgqw9...
# Successfully monitoring /tmp/tmpm7c_64tq...
# Removed temporary file /tmp/tmpm7c_64tq...
# Successfully monitoring /tmp/tmpvx_sviy_...
# Removed temporary file /tmp/tmpvx_sviy_...
# Successfully monitoring /tmp/tmpcupadz4y...
# Removed temporary file /tmp/tmpcupadz4y...
# Successfully monitoring /tmp/tmp31xsbmh5...
# Removed temporary file /tmp/tmp31xsbmh5...
# Successfully monitoring /tmp/tmppuh87q6j...
# Removed temporary file /tmp/tmppuh87q6j...
# Successfully monitoring /tmp/tmpfkw4is75...
# Removed temporary file /tmp/tmpfkw4is75...
# Successfully monitoring /tmp/tmps98lmyqw...
# Removed temporary file /tmp/tmps98lmyqw...
# Successfully monitoring /tmp/tmpn8vdno2n...
# Removed temporary file /tmp/tmpn8vdno2n...
# Successfully monitoring /tmp/tmpubdhu45v...
# Removed temporary file /tmp/tmpubdhu45v...
# Successfully monitoring /tmp/tmpfv8seu57...
# Removed temporary file /tmp/tmpfv8seu57...
# Successfully monitoring /tmp/tmpkb55bryd...
# Removed temporary file /tmp/tmpkb55bryd...
# 15
# Successfully monitoring /tmp/tmpwhn802we...
# Removed temporary file /tmp/tmpwhn802we...
# Successfully monitoring /tmp/tmpwp0cpj9p...
# Removed temporary file /tmp/tmpwp0cpj9p...
# Successfully monitoring /tmp/tmp9655e7jy...
# Removed temporary file /tmp/tmp9655e7jy...
# Successfully monitoring /tmp/tmpghmzc49f...
# Removed temporary file /tmp/tmpghmzc49f...
# Successfully monitoring /tmp/tmph9j_mzxt...
# Removed temporary file /tmp/tmph9j_mzxt...
# Successfully monitoring /tmp/tmpai9m02l6...
# Removed temporary file /tmp/tmpai9m02l6...
# Successfully monitoring /tmp/tmp58wbl_zh...
# Removed temporary file /tmp/tmp58wbl_zh...
# Successfully monitoring /tmp/tmp2tyffmjv...
# Removed temporary file /tmp/tmp2tyffmjv...
# Successfully monitoring /tmp/tmpqk01puw5...
# Removed temporary file /tmp/tmpqk01puw5...
# Successfully monitoring /tmp/tmpojcn25m1...
# Removed temporary file /tmp/tmpojcn25m1...
# Successfully monitoring /tmp/tmpnv6qni7j...
# Removed temporary file /tmp/tmpnv6qni7j...
# Successfully monitoring /tmp/tmp35sxv677...
# Removed temporary file /tmp/tmp35sxv677...
# Successfully monitoring /tmp/tmp11ahum_p...
# Removed temporary file /tmp/tmp11ahum_p...
# Successfully monitoring /tmp/tmp8euh3u8t...
# Removed temporary file /tmp/tmp8euh3u8t...
# Successfully monitoring /tmp/tmp4974odke...
# Removed temporary file /tmp/tmp4974odke...
# Successfully monitoring /tmp/tmpk3y9iuk8...
# Removed temporary file /tmp/tmpk3y9iuk8...
# 16
# Successfully monitoring /tmp/tmpfxocnemv...
# Removed temporary file /tmp/tmpfxocnemv...
# Successfully monitoring /tmp/tmpf1weooxg...
# Removed temporary file /tmp/tmpf1weooxg...
# Successfully monitoring /tmp/tmpsvrl3peo...
# Removed temporary file /tmp/tmpsvrl3peo...
# Successfully monitoring /tmp/tmpc9bj5hfv...
# Removed temporary file /tmp/tmpc9bj5hfv...
# Successfully monitoring /tmp/tmpocsx_kmd...
# Removed temporary file /tmp/tmpocsx_kmd...
# Successfully monitoring /tmp/tmpcpyr2ixp...
# Removed temporary file /tmp/tmpcpyr2ixp...
# Successfully monitoring /tmp/tmpb35spv2c...
# Removed temporary file /tmp/tmpb35spv2c...
# Successfully monitoring /tmp/tmp0rp06q2_...
# Removed temporary file /tmp/tmp0rp06q2_...
# Successfully monitoring /tmp/tmpl_lwyyq4...
# Removed temporary file /tmp/tmpl_lwyyq4...
# Successfully monitoring /tmp/tmp8hwzx67i...
# Removed temporary file /tmp/tmp8hwzx67i...
# Successfully monitoring /tmp/tmpkfhikse8...
# Removed temporary file /tmp/tmpkfhikse8...
# Successfully monitoring /tmp/tmpxzmku89x...
# Removed temporary file /tmp/tmpxzmku89x...
# Successfully monitoring /tmp/tmprpo_2q3w...
# Removed temporary file /tmp/tmprpo_2q3w...
# Successfully monitoring /tmp/tmp9j5ttuhe...
# Removed temporary file /tmp/tmp9j5ttuhe...
# Successfully monitoring /tmp/tmpc53rs6_7...
# Removed temporary file /tmp/tmpc53rs6_7...
# Successfully monitoring /tmp/tmpvaxpltqk...
# Removed temporary file /tmp/tmpvaxpltqk...
# 17
# Successfully monitoring /tmp/tmptsr91t96...
# Removed temporary file /tmp/tmptsr91t96...
# Successfully monitoring /tmp/tmp37o_8ba6...
# Removed temporary file /tmp/tmp37o_8ba6...
# Successfully monitoring /tmp/tmpw24vsuui...
# Removed temporary file /tmp/tmpw24vsuui...
# Successfully monitoring /tmp/tmpgnlzenaa...
# Removed temporary file /tmp/tmpgnlzenaa...
# Successfully monitoring /tmp/tmpsbcou_j7...
# Removed temporary file /tmp/tmpsbcou_j7...
# Successfully monitoring /tmp/tmp2p7t699n...
# Removed temporary file /tmp/tmp2p7t699n...
# Successfully monitoring /tmp/tmpyvmrtbk3...
# Removed temporary file /tmp/tmpyvmrtbk3...
# Successfully monitoring /tmp/tmp1ulndyxw...
# Removed temporary file /tmp/tmp1ulndyxw...
# Successfully monitoring /tmp/tmp33anggfq...
# Removed temporary file /tmp/tmp33anggfq...
# Successfully monitoring /tmp/tmph7b61b8x...
# Removed temporary file /tmp/tmph7b61b8x...
# Successfully monitoring /tmp/tmpzhu_i4o7...
# Removed temporary file /tmp/tmpzhu_i4o7...
# Successfully monitoring /tmp/tmpog7cdity...
# Removed temporary file /tmp/tmpog7cdity...
# Successfully monitoring /tmp/tmpvyfgowcb...
# Removed temporary file /tmp/tmpvyfgowcb...
# Successfully monitoring /tmp/tmp62tnrm7d...
# Removed temporary file /tmp/tmp62tnrm7d...
# Successfully monitoring /tmp/tmp93pogk13...
# Removed temporary file /tmp/tmp93pogk13...
# Successfully monitoring /tmp/tmppw2_zcn9...
# Removed temporary file /tmp/tmppw2_zcn9...
# 18
# Successfully monitoring /tmp/tmpv2arnyb4...
# Removed temporary file /tmp/tmpv2arnyb4...
# Successfully monitoring /tmp/tmp_tvh7bcm...
# Removed temporary file /tmp/tmp_tvh7bcm...
# Successfully monitoring /tmp/tmp8m_12u98...
# Removed temporary file /tmp/tmp8m_12u98...
# Successfully monitoring /tmp/tmpxm_ye8s3...
# Removed temporary file /tmp/tmpxm_ye8s3...
# Successfully monitoring /tmp/tmpd3jlkymu...
# Removed temporary file /tmp/tmpd3jlkymu...
# Successfully monitoring /tmp/tmpfrf_8e43...
# Removed temporary file /tmp/tmpfrf_8e43...
# Successfully monitoring /tmp/tmpcbfacfn8...
# Removed temporary file /tmp/tmpcbfacfn8...
# Successfully monitoring /tmp/tmp3dkb460a...
# Removed temporary file /tmp/tmp3dkb460a...
# Successfully monitoring /tmp/tmp6_6apd3k...
# Removed temporary file /tmp/tmp6_6apd3k...
# Successfully monitoring /tmp/tmp65tn28ij...
# Removed temporary file /tmp/tmp65tn28ij...
# Successfully monitoring /tmp/tmprawie067...
# Removed temporary file /tmp/tmprawie067...
# Successfully monitoring /tmp/tmptzwgvxfn...
# Removed temporary file /tmp/tmptzwgvxfn...
# Successfully monitoring /tmp/tmprfgi45rb...
# Removed temporary file /tmp/tmprfgi45rb...
# Successfully monitoring /tmp/tmpwomktgxu...
# Removed temporary file /tmp/tmpwomktgxu...
# Successfully monitoring /tmp/tmp5demok4p...
# Removed temporary file /tmp/tmp5demok4p...
# Successfully monitoring /tmp/tmp0poirdpe...
# Removed temporary file /tmp/tmp0poirdpe...
# 19
# Successfully monitoring /tmp/tmpemz71clv...
# Removed temporary file /tmp/tmpemz71clv...
# Successfully monitoring /tmp/tmpnm5tp6lf...
# Removed temporary file /tmp/tmpnm5tp6lf...
# Successfully monitoring /tmp/tmpmhh4l1e3...
# Removed temporary file /tmp/tmpmhh4l1e3...
# Successfully monitoring /tmp/tmpy4lsjd08...
# Removed temporary file /tmp/tmpy4lsjd08...
# Successfully monitoring /tmp/tmpwq48roox...
# Removed temporary file /tmp/tmpwq48roox...
# Successfully monitoring /tmp/tmp1r1phl8t...
# Removed temporary file /tmp/tmp1r1phl8t...
# Successfully monitoring /tmp/tmpg2t_t9tz...
# Removed temporary file /tmp/tmpg2t_t9tz...
# Successfully monitoring /tmp/tmprnnl698p...
# Removed temporary file /tmp/tmprnnl698p...
# Successfully monitoring /tmp/tmp9hozb4av...
# Removed temporary file /tmp/tmp9hozb4av...
# Successfully monitoring /tmp/tmp49_dw5me...
# Removed temporary file /tmp/tmp49_dw5me...
# Successfully monitoring /tmp/tmputg92x8u...
# Removed temporary file /tmp/tmputg92x8u...
# Successfully monitoring /tmp/tmpsipk9lo0...
# Removed temporary file /tmp/tmpsipk9lo0...
# Successfully monitoring /tmp/tmpdn5zlajx...
# Removed temporary file /tmp/tmpdn5zlajx...
# Successfully monitoring /tmp/tmpmxn2ihwr...
# Removed temporary file /tmp/tmpmxn2ihwr...
# Successfully monitoring /tmp/tmpk8bee17a...
# Removed temporary file /tmp/tmpk8bee17a...
# Successfully monitoring /tmp/tmp9xtniv6j...
# Removed temporary file /tmp/tmp9xtniv6j...
# 20
# Successfully monitoring /tmp/tmp57mdf63q...
# Removed temporary file /tmp/tmp57mdf63q...
# Successfully monitoring /tmp/tmpyq0v89ip...
# Removed temporary file /tmp/tmpyq0v89ip...
# Successfully monitoring /tmp/tmp2dn5mu8x...
# Removed temporary file /tmp/tmp2dn5mu8x...
# Successfully monitoring /tmp/tmp7t8_fv8w...
# Removed temporary file /tmp/tmp7t8_fv8w...
# Successfully monitoring /tmp/tmpu3d39yng...
# Removed temporary file /tmp/tmpu3d39yng...
# Successfully monitoring /tmp/tmpf5hkvklo...
# Removed temporary file /tmp/tmpf5hkvklo...
# Successfully monitoring /tmp/tmpx5w1phat...
# Removed temporary file /tmp/tmpx5w1phat...
# Successfully monitoring /tmp/tmplbot9yea...
# Removed temporary file /tmp/tmplbot9yea...
# Successfully monitoring /tmp/tmpam8tyr0x...
# Removed temporary file /tmp/tmpam8tyr0x...
# Successfully monitoring /tmp/tmpz0oagfiu...
# Removed temporary file /tmp/tmpz0oagfiu...
# Successfully monitoring /tmp/tmpwbxplwq9...
# Removed temporary file /tmp/tmpwbxplwq9...
# Successfully monitoring /tmp/tmp7g7yy4y0...
# Removed temporary file /tmp/tmp7g7yy4y0...
# Successfully monitoring /tmp/tmpw6xckbqb...
# Removed temporary file /tmp/tmpw6xckbqb...
# Successfully monitoring /tmp/tmp_gtqj3hh...
# Removed temporary file /tmp/tmp_gtqj3hh...
# Successfully monitoring /tmp/tmpcm2e0d5o...
# Removed temporary file /tmp/tmpcm2e0d5o...
# Successfully monitoring /tmp/tmpqjfqjycr...
# Removed temporary file /tmp/tmpqjfqjycr...
# 21
# Successfully monitoring /tmp/tmp1xgt47_w...
# Removed temporary file /tmp/tmp1xgt47_w...
# Successfully monitoring /tmp/tmptean7izz...
# Removed temporary file /tmp/tmptean7izz...
# Successfully monitoring /tmp/tmp57sm_smi...
# Removed temporary file /tmp/tmp57sm_smi...
# Successfully monitoring /tmp/tmp0231vmib...
# Removed temporary file /tmp/tmp0231vmib...
# Successfully monitoring /tmp/tmp40u1j56j...
# Removed temporary file /tmp/tmp40u1j56j...
# Successfully monitoring /tmp/tmp02yp6wkc...
# Removed temporary file /tmp/tmp02yp6wkc...
# Successfully monitoring /tmp/tmpj9s_zkrs...
# Removed temporary file /tmp/tmpj9s_zkrs...
# Successfully monitoring /tmp/tmpe_utld1o...
# Removed temporary file /tmp/tmpe_utld1o...
# Successfully monitoring /tmp/tmpri146ndl...
# Removed temporary file /tmp/tmpri146ndl...
# Successfully monitoring /tmp/tmp5vkooawn...
# Removed temporary file /tmp/tmp5vkooawn...
# Successfully monitoring /tmp/tmpwxnw23yt...
# Removed temporary file /tmp/tmpwxnw23yt...
# Successfully monitoring /tmp/tmpfqoamn24...
# Removed temporary file /tmp/tmpfqoamn24...
# Successfully monitoring /tmp/tmpqksf_d27...
# Removed temporary file /tmp/tmpqksf_d27...
# Successfully monitoring /tmp/tmpsaygnuql...
# Removed temporary file /tmp/tmpsaygnuql...
# Successfully monitoring /tmp/tmpzkc14lvo...
# Removed temporary file /tmp/tmpzkc14lvo...
# Successfully monitoring /tmp/tmp2dboeh18...
# Removed temporary file /tmp/tmp2dboeh18...
# 22
# Successfully monitoring /tmp/tmpb8q3q32k...
# Removed temporary file /tmp/tmpb8q3q32k...
# Successfully monitoring /tmp/tmp_l15yai6...
# Removed temporary file /tmp/tmp_l15yai6...
# Successfully monitoring /tmp/tmpgwye3iwh...
# Removed temporary file /tmp/tmpgwye3iwh...
# Successfully monitoring /tmp/tmp3gbahjo0...
# Removed temporary file /tmp/tmp3gbahjo0...
# Successfully monitoring /tmp/tmparibz_7k...
# Removed temporary file /tmp/tmparibz_7k...
# Successfully monitoring /tmp/tmpkokatl7p...
# Removed temporary file /tmp/tmpkokatl7p...
# Successfully monitoring /tmp/tmpbywntyay...
# Removed temporary file /tmp/tmpbywntyay...
# Successfully monitoring /tmp/tmp1ept03uz...
# Removed temporary file /tmp/tmp1ept03uz...
# Successfully monitoring /tmp/tmprks95pd9...
# Removed temporary file /tmp/tmprks95pd9...
# Successfully monitoring /tmp/tmp4oqwuoq3...
# Removed temporary file /tmp/tmp4oqwuoq3...
# Successfully monitoring /tmp/tmpex1ee7e_...
# Removed temporary file /tmp/tmpex1ee7e_...
# Successfully monitoring /tmp/tmpea539aeh...
# Removed temporary file /tmp/tmpea539aeh...
# Successfully monitoring /tmp/tmpqvbj68tc...
# Removed temporary file /tmp/tmpqvbj68tc...
# Successfully monitoring /tmp/tmpu4_n46lo...
# Removed temporary file /tmp/tmpu4_n46lo...
# Successfully monitoring /tmp/tmpkdo6wclk...
# Removed temporary file /tmp/tmpkdo6wclk...
# Successfully monitoring /tmp/tmp272v762k...
# Removed temporary file /tmp/tmp272v762k...
# 23
# Successfully monitoring /tmp/tmplsbhk51e...
# Removed temporary file /tmp/tmplsbhk51e...
# Successfully monitoring /tmp/tmpbf2hk443...
# Removed temporary file /tmp/tmpbf2hk443...
# Successfully monitoring /tmp/tmp5hx2j5zq...
# Removed temporary file /tmp/tmp5hx2j5zq...
# Successfully monitoring /tmp/tmpvuvlwvlz...
# Removed temporary file /tmp/tmpvuvlwvlz...
# Successfully monitoring /tmp/tmp2ifaa95_...
# Removed temporary file /tmp/tmp2ifaa95_...
# Successfully monitoring /tmp/tmp0mchlxvq...
# Removed temporary file /tmp/tmp0mchlxvq...
# Successfully monitoring /tmp/tmp3scf2aip...
# Removed temporary file /tmp/tmp3scf2aip...
# Successfully monitoring /tmp/tmpdo_cha09...
# Removed temporary file /tmp/tmpdo_cha09...
# Successfully monitoring /tmp/tmp8wicnbq5...
# Removed temporary file /tmp/tmp8wicnbq5...
# Successfully monitoring /tmp/tmp_dk1es77...
# Removed temporary file /tmp/tmp_dk1es77...
# Successfully monitoring /tmp/tmpa4vz8f6r...
# Removed temporary file /tmp/tmpa4vz8f6r...
# Successfully monitoring /tmp/tmpu75c6k57...
# Removed temporary file /tmp/tmpu75c6k57...
# Successfully monitoring /tmp/tmplsar_n0s...
# Removed temporary file /tmp/tmplsar_n0s...
# Successfully monitoring /tmp/tmpc55yn3of...
# Removed temporary file /tmp/tmpc55yn3of...
# Successfully monitoring /tmp/tmpyw9lwz36...
# Removed temporary file /tmp/tmpyw9lwz36...
# Successfully monitoring /tmp/tmp773h89u2...
# Removed temporary file /tmp/tmp773h89u2...
# 24
# Successfully monitoring /tmp/tmpb4q1ivl9...
# Removed temporary file /tmp/tmpb4q1ivl9...
# Successfully monitoring /tmp/tmph5vk9a_i...
# Removed temporary file /tmp/tmph5vk9a_i...
# Successfully monitoring /tmp/tmprock8mja...
# Removed temporary file /tmp/tmprock8mja...
# Successfully monitoring /tmp/tmpac668t9x...
# Removed temporary file /tmp/tmpac668t9x...
# Successfully monitoring /tmp/tmpu1a_30nl...
# Removed temporary file /tmp/tmpu1a_30nl...
# Successfully monitoring /tmp/tmptiphwdwi...
# Removed temporary file /tmp/tmptiphwdwi...
# Successfully monitoring /tmp/tmp4jxf7ilu...
# Removed temporary file /tmp/tmp4jxf7ilu...
# Successfully monitoring /tmp/tmp01to5s7u...
# Removed temporary file /tmp/tmp01to5s7u...
# Successfully monitoring /tmp/tmp8gmoav7c...
# Removed temporary file /tmp/tmp8gmoav7c...
# Successfully monitoring /tmp/tmptlswww12...
# Removed temporary file /tmp/tmptlswww12...
# Successfully monitoring /tmp/tmprb_arvgs...
# Removed temporary file /tmp/tmprb_arvgs...
# Successfully monitoring /tmp/tmp0f0510oz...
# Removed temporary file /tmp/tmp0f0510oz...
# Successfully monitoring /tmp/tmp14ij40t0...
# Removed temporary file /tmp/tmp14ij40t0...
# Successfully monitoring /tmp/tmpcii0r4d3...
# Removed temporary file /tmp/tmpcii0r4d3...
# Successfully monitoring /tmp/tmp9gvnlnn_...
# Removed temporary file /tmp/tmp9gvnlnn_...
# Successfully monitoring /tmp/tmpjl05omev...
# Removed temporary file /tmp/tmpjl05omev...
# 25
# Successfully monitoring /tmp/tmpfhbs9a3u...
# Removed temporary file /tmp/tmpfhbs9a3u...
# Successfully monitoring /tmp/tmpohi90z58...
# Removed temporary file /tmp/tmpohi90z58...
# Successfully monitoring /tmp/tmp4us8ut2b...
# Removed temporary file /tmp/tmp4us8ut2b...
# Successfully monitoring /tmp/tmprh5a74t9...
# Removed temporary file /tmp/tmprh5a74t9...
# Successfully monitoring /tmp/tmp60kcrfi_...
# Removed temporary file /tmp/tmp60kcrfi_...
# Successfully monitoring /tmp/tmpb459kfvz...
# Removed temporary file /tmp/tmpb459kfvz...
# Successfully monitoring /tmp/tmpi3pyz5b3...
# Removed temporary file /tmp/tmpi3pyz5b3...
# Successfully monitoring /tmp/tmpqwdbeyok...
# Removed temporary file /tmp/tmpqwdbeyok...
# Successfully monitoring /tmp/tmpjpwau2l3...
# Removed temporary file /tmp/tmpjpwau2l3...
# Successfully monitoring /tmp/tmpe38ow1_5...
# Removed temporary file /tmp/tmpe38ow1_5...
# Successfully monitoring /tmp/tmpj6esy3h_...
# Removed temporary file /tmp/tmpj6esy3h_...
# Successfully monitoring /tmp/tmpq6st9_6m...
# Removed temporary file /tmp/tmpq6st9_6m...
# Successfully monitoring /tmp/tmp5fqgbbc5...
# Removed temporary file /tmp/tmp5fqgbbc5...
# Successfully monitoring /tmp/tmpkmbqc5nm...
# Removed temporary file /tmp/tmpkmbqc5nm...
# Successfully monitoring /tmp/tmpej1lbxna...
# Removed temporary file /tmp/tmpej1lbxna...
# Successfully monitoring /tmp/tmp14bic0w7...
# Removed temporary file /tmp/tmp14bic0w7...
# 26
# Successfully monitoring /tmp/tmpn_20eatb...
# Removed temporary file /tmp/tmpn_20eatb...
# Successfully monitoring /tmp/tmpv5_e3t4l...
# Removed temporary file /tmp/tmpv5_e3t4l...
# Successfully monitoring /tmp/tmppe7mjfw8...
# Removed temporary file /tmp/tmppe7mjfw8...
# Successfully monitoring /tmp/tmpzcdl_x0l...
# Removed temporary file /tmp/tmpzcdl_x0l...
# Successfully monitoring /tmp/tmp_an9qft1...
# Removed temporary file /tmp/tmp_an9qft1...
# Successfully monitoring /tmp/tmpe1a4y2e6...
# Removed temporary file /tmp/tmpe1a4y2e6...
# Successfully monitoring /tmp/tmpwvht47ul...
# Removed temporary file /tmp/tmpwvht47ul...
# Successfully monitoring /tmp/tmp45vf0hc_...
# Removed temporary file /tmp/tmp45vf0hc_...
# Successfully monitoring /tmp/tmp2pyinjxn...
# Removed temporary file /tmp/tmp2pyinjxn...
# Successfully monitoring /tmp/tmpsm591o1c...
# Removed temporary file /tmp/tmpsm591o1c...
# Successfully monitoring /tmp/tmpl6wbai54...
# Removed temporary file /tmp/tmpl6wbai54...
# Successfully monitoring /tmp/tmp0n8oyp3q...
# Removed temporary file /tmp/tmp0n8oyp3q...
# Successfully monitoring /tmp/tmpovwvo9lf...
# Removed temporary file /tmp/tmpovwvo9lf...
# Successfully monitoring /tmp/tmpu7jr5057...
# Removed temporary file /tmp/tmpu7jr5057...
# Successfully monitoring /tmp/tmpc4t1ybyg...
# Removed temporary file /tmp/tmpc4t1ybyg...
# Successfully monitoring /tmp/tmppgd9im27...
# Removed temporary file /tmp/tmppgd9im27...
# 27
# Successfully monitoring /tmp/tmpqiyn0k44...
# Removed temporary file /tmp/tmpqiyn0k44...
# Successfully monitoring /tmp/tmptgw0m3be...
# Removed temporary file /tmp/tmptgw0m3be...
# Successfully monitoring /tmp/tmpdwk7svy3...
# Removed temporary file /tmp/tmpdwk7svy3...
# Successfully monitoring /tmp/tmpc3kxr1z8...
# Removed temporary file /tmp/tmpc3kxr1z8...
# Successfully monitoring /tmp/tmpizj2s9n0...
# Removed temporary file /tmp/tmpizj2s9n0...
# Successfully monitoring /tmp/tmpcw0inbtm...
# Removed temporary file /tmp/tmpcw0inbtm...
# Successfully monitoring /tmp/tmpn4xitjrk...
# Removed temporary file /tmp/tmpn4xitjrk...
# Successfully monitoring /tmp/tmp49n28gw_...
# Removed temporary file /tmp/tmp49n28gw_...
# Successfully monitoring /tmp/tmp6x0tgrf0...
# Removed temporary file /tmp/tmp6x0tgrf0...
# Successfully monitoring /tmp/tmpe6t_awvm...
# Removed temporary file /tmp/tmpe6t_awvm...
# Successfully monitoring /tmp/tmpxor7nom6...
# Removed temporary file /tmp/tmpxor7nom6...
# Successfully monitoring /tmp/tmpcivs538p...
# Removed temporary file /tmp/tmpcivs538p...
# Successfully monitoring /tmp/tmpjbqf7od2...
# Removed temporary file /tmp/tmpjbqf7od2...
# Successfully monitoring /tmp/tmpm7secn2j...
# Removed temporary file /tmp/tmpm7secn2j...
# Successfully monitoring /tmp/tmpo6jog4xs...
# Removed temporary file /tmp/tmpo6jog4xs...
# Successfully monitoring /tmp/tmpkhr5rvy5...
# Removed temporary file /tmp/tmpkhr5rvy5...
# 28
# Successfully monitoring /tmp/tmpm1lnfb54...
# Removed temporary file /tmp/tmpm1lnfb54...
# Successfully monitoring /tmp/tmp4cy8_r01...
# Removed temporary file /tmp/tmp4cy8_r01...
# Successfully monitoring /tmp/tmp8nh6dh54...
# Removed temporary file /tmp/tmp8nh6dh54...
# Successfully monitoring /tmp/tmpp4oyaej_...
# Removed temporary file /tmp/tmpp4oyaej_...
# Successfully monitoring /tmp/tmpyz3q1v96...
# Removed temporary file /tmp/tmpyz3q1v96...
# Successfully monitoring /tmp/tmpdu4etuqp...
# Removed temporary file /tmp/tmpdu4etuqp...
# Successfully monitoring /tmp/tmp4aa8vm8p...
# Removed temporary file /tmp/tmp4aa8vm8p...
# Successfully monitoring /tmp/tmpunfq08ig...
# Removed temporary file /tmp/tmpunfq08ig...
# Successfully monitoring /tmp/tmpqxfmbqff...
# Removed temporary file /tmp/tmpqxfmbqff...
# Successfully monitoring /tmp/tmpno24diat...
# Removed temporary file /tmp/tmpno24diat...
# Successfully monitoring /tmp/tmpl35w90dg...
# Removed temporary file /tmp/tmpl35w90dg...
# Successfully monitoring /tmp/tmpi61vote3...
# Removed temporary file /tmp/tmpi61vote3...
# Successfully monitoring /tmp/tmpcnn847th...
# Removed temporary file /tmp/tmpcnn847th...
# Successfully monitoring /tmp/tmp7qbzxh1s...
# Removed temporary file /tmp/tmp7qbzxh1s...
# Successfully monitoring /tmp/tmp5q_tq6vx...
# Removed temporary file /tmp/tmp5q_tq6vx...
# Successfully monitoring /tmp/tmp1bf9uk1f...
# Removed temporary file /tmp/tmp1bf9uk1f...
# 29
# Successfully monitoring /tmp/tmp3nab59u8...
# Removed temporary file /tmp/tmp3nab59u8...
# Successfully monitoring /tmp/tmp8xgl21et...
# Removed temporary file /tmp/tmp8xgl21et...
# Successfully monitoring /tmp/tmpk2r5tx9v...
# Removed temporary file /tmp/tmpk2r5tx9v...
# Successfully monitoring /tmp/tmphavftv0f...
# Removed temporary file /tmp/tmphavftv0f...
# Successfully monitoring /tmp/tmpzcmlnpch...
# Removed temporary file /tmp/tmpzcmlnpch...
# Successfully monitoring /tmp/tmpt73h3jkm...
# Removed temporary file /tmp/tmpt73h3jkm...
# Successfully monitoring /tmp/tmpry9efuus...
# Removed temporary file /tmp/tmpry9efuus...
# Successfully monitoring /tmp/tmp6h4v5tl2...
# Removed temporary file /tmp/tmp6h4v5tl2...
# Successfully monitoring /tmp/tmp9ngcftdy...
# Removed temporary file /tmp/tmp9ngcftdy...
# Successfully monitoring /tmp/tmp27879tln...
# Removed temporary file /tmp/tmp27879tln...
# Successfully monitoring /tmp/tmpmlllyt0o...
# Removed temporary file /tmp/tmpmlllyt0o...
# Successfully monitoring /tmp/tmph50_tnsl...
# Removed temporary file /tmp/tmph50_tnsl...
# Successfully monitoring /tmp/tmpltlrlgb3...
# Removed temporary file /tmp/tmpltlrlgb3...
# Successfully monitoring /tmp/tmpjkh87ti8...
# Removed temporary file /tmp/tmpjkh87ti8...
# Successfully monitoring /tmp/tmprwqmkirv...
# Removed temporary file /tmp/tmprwqmkirv...
# Successfully monitoring /tmp/tmp635qap1b...
# Removed temporary file /tmp/tmp635qap1b...
# 30
# Successfully monitoring /tmp/tmpm_wqvnyw...
# Removed temporary file /tmp/tmpm_wqvnyw...
# Successfully monitoring /tmp/tmp8f8bn0j7...
# Removed temporary file /tmp/tmp8f8bn0j7...
# Successfully monitoring /tmp/tmpy03z0j72...
# Removed temporary file /tmp/tmpy03z0j72...
# Successfully monitoring /tmp/tmphm1gcesz...
# Removed temporary file /tmp/tmphm1gcesz...
# Successfully monitoring /tmp/tmpbm15ijb4...
# Removed temporary file /tmp/tmpbm15ijb4...
# Successfully monitoring /tmp/tmpivr79gq3...
# Removed temporary file /tmp/tmpivr79gq3...
# Successfully monitoring /tmp/tmpwickjx4j...
# Removed temporary file /tmp/tmpwickjx4j...
# Successfully monitoring /tmp/tmp5o8_xcy3...
# Removed temporary file /tmp/tmp5o8_xcy3...
# Successfully monitoring /tmp/tmp19pyx7r1...
# Removed temporary file /tmp/tmp19pyx7r1...
# Successfully monitoring /tmp/tmpk6aw37ra...
# Removed temporary file /tmp/tmpk6aw37ra...
# Successfully monitoring /tmp/tmpwwb33w7w...
# Removed temporary file /tmp/tmpwwb33w7w...
# Successfully monitoring /tmp/tmpejf804ze...
# Removed temporary file /tmp/tmpejf804ze...
# Successfully monitoring /tmp/tmpv1wc8m4z...
# Removed temporary file /tmp/tmpv1wc8m4z...
# Successfully monitoring /tmp/tmp45bu6m8x...
# Removed temporary file /tmp/tmp45bu6m8x...
# Successfully monitoring /tmp/tmp2004sk9h...
# Removed temporary file /tmp/tmp2004sk9h...
# Successfully monitoring /tmp/tmpr6jh5t0l...
# Removed temporary file /tmp/tmpr6jh5t0l...
# 31
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-18-211b974cc785> in main(filepath, month)
#      33                                    '2017-' + month + '/'
#      34                                    '2017-' + month + '-' + i +'/conn.*.log.gz')
# ---> 35         conn = CleanConn(conn)
#      36         if month == '08':
#      37             conn2 = Aug_Mapping(conn,Macone,MacExa,IPLook)
#
# <ipython-input-10-dfa5090c6f7e> in CleanConn(conn)
#       1 def CleanConn(conn):
#       2     #only external data
# ----> 3     conn = conn[conn.local_resp.apply(lambda x: not x)]
#       4     conn = conn[conn.proto == 'tcp']
#       5     #select column
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'MultiLogToDataFrame' object has no attribute 'local_resp'
